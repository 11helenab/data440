# %%
from src.data import make_data, save_data, load_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data import make_data, save_data, load_data
#
# ModuleNotFoundError: No module named 'src.data'
